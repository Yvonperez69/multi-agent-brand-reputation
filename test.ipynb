# %%
a =input()
print(type(a))
# Out:
# <class 'str'>

# %%
from datetime import datetime
day = datetime.now().strftime("%d_%m_%Y")
print(day)
# Out:
# 09_04_2026

# %%
import time 

t1 = time.time()
time.sleep(4)
t2 = time.time()
print(t2-t1)
# Out:
# 4.001084089279175

# %%
import report
import json
import os 

os.listdir("report")
# Out:
# ['Nike_2026-04-09.json',
#  'Apple_2026-05-01.json',
#  'JBL_2026-04-14.json',
#  'Nike_2026-05-01.json',
#  'Total Energie_2026-04-14.json',
#  'Samsung_2026-04-14.json',
#  'Nike_2026-04-10.json',
#  'Mistral IA_2026-04-10.json']

# %%
a = [1,23,5,7,56,657]

a[-3:]
# Out:
# [7, 56, 657]

# %%
a = ["marque", "réputation", "rapport"]
b = "ezeziuhui ofho hz. zha hze hfzç! marque uezfbui zfuzu"
if any(kw in b for kw in a):
    print(True)
else :
    print(False)
# Out:
# True
